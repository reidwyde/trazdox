# %% [markdown]
# ## System 1
#
# Copyright: Reid Wyde 2020
#
# last updated: 3.12.20

# %%
#data
from get_tumor_db import get_tumor_db
from parse_tumor_db import parse_tumor_db

#visualization
import plot_data

#treatment
import treatment_model as tm

#growth model
from growth_model import growth_model_1

#forward model
import rk_utils

#arrays
import numpy as np

#file system
import os

#CSV read
import pandas as pd

import warnings
warnings.filterwarnings("ignore")



np.random.seed(123)
# Out:
# teatment impulse

# %%
tumor_size_db = get_tumor_db()
ts, Ts, sigmas = parse_tumor_db(tumor_size_db)
plot_data.plot_tumor_data(ts, Ts)

# %% [markdown]
# ## Growth Model 1
#
#
# $$ \frac{d \phi_t}{dt} = r \phi_t - \lambda_h \phi_h \phi_t  - \lambda_{hd} \phi_h \phi_d \phi_t $$
#
# $$ \frac{d \phi_d}{dt} = - \tau_d \phi_d + \delta (t - \eta_d) D_d $$
#
# $$ \frac{d \phi_h}{dt} = - \tau_h \phi_h + \delta (t - \eta_h) D_h e^{-\lambda_{dh} \phi_d} $$
#
# r, lambda_h, lambda_d, lambda_hd, tau_d, tau_h, lambda_dh

# %% [markdown]
# ## Simulate with fixed parameters

# %%
r = 6.19e-2
lambda_h = 2.89e-2
lambda_hd = 7.03e-2
tau_d = 1.72e-3
tau_h = 4.17e-3
lambda_dh = 9.78
sim_params = np.array([r, lambda_h, lambda_hd, tau_d, tau_h, lambda_dh])

growth_model_1().sim_graph_model(sim_params)
# Out:
# r = 0.0619
# lambda_h = 0.0289
# lambda_hd = 0.0703
# tau_d = 0.00172
# tau_h = 0.00417
# lambda_dh = 9.78

# %% [markdown]
# ## Fit parameters with MCMC

# %%
growth_model_1().fit_sim_graph_model()
# Out:
# Sequential sampling (40 chains in 1 job)
# CompoundStep
# >Metropolis: [lambda_dh]
# >Metropolis: [tau_h]
# >Metropolis: [tau_d]
# >Metropolis: [lambda_hd]
# >Metropolis: [lambda_h]
# >Metropolis: [r]
# Sampling chain 0, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:31<00:00, 32.65it/s]
# Sampling chain 1, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:28<00:00, 34.00it/s]
# Sampling chain 2, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:24<00:00, 35.34it/s]
# Sampling chain 3, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:24<00:00, 35.40it/s]
# Sampling chain 4, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.22it/s]
# Sampling chain 5, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.27it/s]
# Sampling chain 6, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.79it/s]
# Sampling chain 7, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:25<00:00, 34.98it/s]
# Sampling chain 8, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:24<00:00, 35.34it/s]
# Sampling chain 9, 0 divergences: 100%|█████████████████████████████████████████████| 3000/3000 [01:25<00:00, 34.92it/s]
# Sampling chain 10, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.12it/s]
# Sampling chain 11, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.00it/s]
# Sampling chain 12, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 34.99it/s]
# Sampling chain 13, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.18it/s]
# Sampling chain 14, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 34.91it/s]
# Sampling chain 15, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.24it/s]
# Sampling chain 16, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:26<00:00, 34.73it/s]
# Sampling chain 17, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:26<00:00, 34.88it/s]
# Sampling chain 18, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:26<00:00, 34.81it/s]
# Sampling chain 19, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:26<00:00, 34.72it/s]
# Sampling chain 20, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:26<00:00, 34.54it/s]
# Sampling chain 21, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:25<00:00, 35.10it/s]
# Sampling chain 22, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [13:21<00:00,  3.74it/s]
# Sampling chain 23, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:29<00:00, 33.44it/s]
# Sampling chain 24, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:29<00:00, 33.54it/s]
# Sampling chain 25, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.72it/s]
# Sampling chain 26, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:29<00:00, 33.60it/s]
# Sampling chain 27, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.15it/s]
# Sampling chain 28, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.17it/s]
# Sampling chain 29, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 34.07it/s]
# Sampling chain 30, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.47it/s]
# Sampling chain 31, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 34.00it/s]
# Sampling chain 32, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.75it/s]
# Sampling chain 33, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 34.07it/s]
# Sampling chain 34, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.76it/s]
# Sampling chain 35, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.20it/s]
# Sampling chain 36, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:27<00:00, 34.18it/s]
# Sampling chain 37, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.81it/s]
# Sampling chain 38, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.90it/s]
# Sampling chain 39, 0 divergences: 100%|████████████████████████████████████████████| 3000/3000 [01:28<00:00, 33.95it/s]
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 10% for some parameters.
# 100%|███████████████████████████████████████████████████████████████████████████| 80000/80000 [05:46<00:00, 230.79it/s]
# r = 0.061
# lambda_h = 0.041
# lambda_hd = 0.136
# tau_d = 0.041
# tau_h = 0.036
# lambda_dh = 25.143
