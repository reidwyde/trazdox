# %% [markdown]
# ## System 1
#
# Copyright: Reid Wyde 2020
#
# last updated: 3.12.20

# %%
#data
from get_tumor_db import get_tumor_db
from parse_tumor_db import parse_tumor_db

#visualization
import plot_data

#treatment
import treatment_model as tm

#growth model
from growth_model import growth_model_1

#forward model
import rk_utils

#arrays
import numpy as np

#file system
import os

#CSV read
import pandas as pd

import warnings
warnings.filterwarnings("ignore")



np.random.seed(123)
# Out:
# teatment impulse

# %%
tumor_size_db = get_tumor_db()
ts, Ts, sigmas = parse_tumor_db(tumor_size_db)
plot_data.plot_tumor_data(ts, Ts)

# %% [markdown]
# ## Growth Model 1
#
#
# $$ \frac{d \phi_t}{dt} = r \phi_t - \lambda_h \phi_h \phi_t  - \lambda_{hd} \phi_h \phi_d \phi_t $$
#
# $$ \frac{d \phi_d}{dt} = - \tau_d \phi_d + \delta (t - \eta_d) D_d $$
#
# $$ \frac{d \phi_h}{dt} = - \tau_h \phi_h + \delta (t - \eta_h) D_h e^{-\lambda_{dh} \phi_d} $$
#
# r, lambda_h, lambda_d, lambda_hd, tau_d, tau_h, lambda_dh

# %% [markdown]
# ## Simulate with fixed parameters

# %%
r = 6.19e-2
lambda_h = 2.89e-2
lambda_hd = 7.03e-2
tau_d = 1.72e-3
tau_h = 4.17e-3
lambda_dh = 9.78
sim_params = np.array([r, lambda_h, lambda_hd, tau_d, tau_h, lambda_dh])

growth_model_1().sim_graph_model(sim_params)
# Out:
# r = 0.0619
# lambda_h = 0.0289
# lambda_hd = 0.0703
# tau_d = 0.00172
# tau_h = 0.00417
# lambda_dh = 9.78

# %% [markdown]
# ## Fit parameters with MCMC

# %%
growth_model_1().fit_sim_graph_model()
# Out:
# Sequential sampling (20 chains in 1 job)
# CompoundStep
# >Metropolis: [lambda_dh]
# >Metropolis: [tau_h]
# >Metropolis: [tau_d]
# >Metropolis: [lambda_hd]
# >Metropolis: [lambda_h]
# >Metropolis: [r]
# Sampling chain 0, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:48<00:00, 31.15it/s]
# Sampling chain 1, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:47<00:00, 31.39it/s]
# Sampling chain 2, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:47<00:00, 31.56it/s]
# Sampling chain 3, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:46<00:00, 32.01it/s]
# Sampling chain 4, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:48<00:00, 31.09it/s]
# Sampling chain 5, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:49<00:00, 30.21it/s]
# Sampling chain 6, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:48<00:00, 31.07it/s]
# Sampling chain 7, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:51<00:00, 29.40it/s]
# Sampling chain 8, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:55<00:00, 27.11it/s]
# Sampling chain 9, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [00:52<00:00, 28.68it/s]
# Sampling chain 10, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [00:54<00:00, 27.47it/s]
# Sampling chain 11, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [00:54<00:00, 27.38it/s]
# Sampling chain 12, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:02<00:00, 24.05it/s]
# Sampling chain 13, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:08<00:00, 21.94it/s]
# Sampling chain 14, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:13<00:00, 20.28it/s]
# Sampling chain 15, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:07<00:00, 22.18it/s]
# Sampling chain 16, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:11<00:00, 21.07it/s]
# Sampling chain 17, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:05<00:00, 22.87it/s]
# Sampling chain 18, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:16<00:00, 19.58it/s]
# Sampling chain 19, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:08<00:00, 22.05it/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [01:41<00:00, 196.64it/s]
# r = 0.061
# lambda_h = 0.042
# lambda_hd = 0.137
# tau_d = 0.04
# tau_h = 0.037
# lambda_dh = 25.066
