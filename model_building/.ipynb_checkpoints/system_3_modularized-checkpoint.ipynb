# %% [markdown]
# ## System 3
#
# Copyright: Reid Wyde 2020
#
# last updated: 3.12.20

# %%
#data
from get_tumor_db import get_tumor_db
from parse_tumor_db import parse_tumor_db

#visualization
import plot_data

#treatment
import treatment_model as tm

#growth model
from growth_model import growth_model_3

#forward model
import rk_utils

#arrays
import numpy as np

#file system
import os

#CSV read
import pandas as pd

import warnings
warnings.filterwarnings("ignore")



np.random.seed(123)
# Out:
# teatment impulse

# %%
tumor_size_db = get_tumor_db()
ts, Ts, sigmas = parse_tumor_db(tumor_size_db)
plot_data.plot_tumor_data(ts, Ts)

# %% [markdown]
# ## Growth Model 3
#
# $$ \frac{d \phi_t}{dt} = r \phi_t - \lambda_h \phi_h \phi_t - \lambda_o \phi_o \phi_t $$
#
# $$ \frac{d \phi_o}{dt} = \lambda_{odh} \phi_d \phi_h - \tau_o \phi_o $$
#
# $$ \frac{d \phi_d}{dt} = - \tau_d \phi_d + \delta (t - \eta_d) D_d $$
#
# $$ \frac{d \phi_h}{dt} = - \tau_h \phi_h + \delta (t - \eta_h) D_h e^{-\lambda_{dh} \phi_d} $$
#
# r, lambda_h, lambda_o, lambda_odh, tau_o, tau_d, tau_h, lambda_dh

# %% [markdown]
# ## Simulate with fixed parameters

# %%
r = 6.19e-2
lambda_h = 2.89e-2
lambda_o = 1e-1
lambda_odh = 7.03e-2
tau_o = 1e-1
tau_d = 1.72e-3
tau_h = 4.17e-3
lambda_dh = 9.78
        
sim_params = np.array([r, lambda_h, lambda_o, lambda_o, tau_o, tau_d, tau_h, lambda_dh])

growth_model_3().sim_graph_model(sim_params)
# Out:
# r = 0.0619
# lambda_h = 0.0289
# lambda_o = 0.1
# lambda_odh = 0.1
# tau_o = 0.1
# tau_d = 0.00172
# tau_h = 0.00417
# lambda_dh = 9.78

# %% [markdown]
# ## Fit parameters with MCMC

# %%
growth_model_3().fit_sim_graph_model()
# Out:
# Sequential sampling (40 chains in 1 job)
# CompoundStep
# >Metropolis: [lambda_dh]
# >Metropolis: [tau_h]
# >Metropolis: [tau_d]
# >Metropolis: [tau_o]
# >Metropolis: [lambda_odh]
# >Metropolis: [lambda_o]
# >Metropolis: [lambda_h]
# >Metropolis: [r]
# Sampling chain 0, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.56it/s]
# Sampling chain 1, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.74it/s]
# Sampling chain 2, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.67it/s]
# Sampling chain 3, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.60it/s]
# Sampling chain 4, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.41it/s]
# Sampling chain 5, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.80it/s]
# Sampling chain 6, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.63it/s]
# Sampling chain 7, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.57it/s]
# Sampling chain 8, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.67it/s]
# Sampling chain 9, 0 divergences: 100%|█████████████████████████████████████████████| 1500/1500 [01:05<00:00, 22.95it/s]
# Sampling chain 10, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.41it/s]
# Sampling chain 11, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.42it/s]
# Sampling chain 12, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.40it/s]
# Sampling chain 13, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.55it/s]
# Sampling chain 14, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.45it/s]
# Sampling chain 15, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.47it/s]
# Sampling chain 16, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.16it/s]
# Sampling chain 17, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.26it/s]
# Sampling chain 18, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.30it/s]
# Sampling chain 19, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:06<00:00, 22.52it/s]
# Sampling chain 20, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.15it/s]
# Sampling chain 21, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.44it/s]
# Sampling chain 22, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:04<00:00, 23.32it/s]
# Sampling chain 23, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.75it/s]
# Sampling chain 24, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.72it/s]
# Sampling chain 25, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:07<00:00, 22.33it/s]
# Sampling chain 26, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.72it/s]
# Sampling chain 27, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:03<00:00, 23.71it/s]
# Sampling chain 28, 0 divergences: 100%|██████████████████████████████████████████| 1500/1500 [3:35:03<00:00,  8.60s/it]
# Sampling chain 29, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.46it/s]
# Sampling chain 30, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:22<00:00, 18.19it/s]
# Sampling chain 31, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:19<00:00, 18.76it/s]
# Sampling chain 32, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:20<00:00, 18.71it/s]
# Sampling chain 33, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.30it/s]
# Sampling chain 34, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:22<00:00, 18.09it/s]
# Sampling chain 35, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.32it/s]
# Sampling chain 36, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.38it/s]
# Sampling chain 37, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.30it/s]
# Sampling chain 38, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:20<00:00, 18.61it/s]
# Sampling chain 39, 0 divergences: 100%|████████████████████████████████████████████| 1500/1500 [01:21<00:00, 18.49it/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [03:18<00:00, 201.66it/s]
# r = 0.061
# lambda_h = 0.053
# lambda_o = 0.386
# lambda_odh = 0.346
# tau_o = 0.166
# tau_d = 0.436
# tau_h = 0.066
# lambda_dh = 32.645
