# %%
import growth_model
import numpy as np
from get_tumor_db import get_tumor_db
from parse_tumor_db import parse_tumor_db
import matplotlib.pyplot as plt
# Out:
# teatment impulse

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model1 = growth_model.growth_model_1()
def get_mod_1_params():
    r = 6.191238e-2 #0.061
    lambda_h = 2.885953e-2 #0.041
    lambda_hd = 7.029930e-2  #0.136
    tau_d = 1.720374e-3 #0.041
    tau_h = 4.171260e-3 #0.036
    lambda_dh = 9.776661e0 #25.143
    return [r, lambda_h, lambda_hd, tau_d, tau_h, lambda_dh]

model1.sim_graph_model(get_mod_1_params())
# Out:
# r = 0.06191238
# lambda_h = 0.02885953
# lambda_hd = 0.0702993
# tau_d = 0.001720374
# tau_h = 0.00417126
# lambda_dh = 9.776661

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model2 = growth_model.growth_model_2()
def get_mod_2_params():
    r = 6.198720e-2 #0.061
    lambda_h = 2.894577e-2 #0.052
    lambda_ho = 2.657592e-1 #0.407
    lambda_od = 1.337581e1 #0.442
    tau_o = 4.903494e1 #0.152
    tau_d = 4.864478e-3 #0.432
    tau_h = 5.076163e-3 #0.064
    lambda_dh = 9.995652e0 #34.167
    return [r, lambda_h, lambda_ho, lambda_od, tau_o, tau_d, tau_h, lambda_dh]
    

model2.sim_graph_model(get_mod_2_params())
# Out:
# r = 0.0619872
# lambda_h = 0.02894577
# lambda_ho = 0.2657592
# lambda_od = 13.37581
# tau_o = 49.03494
# tau_d = 0.004864478
# tau_h = 0.005076163
# lambda_dh = 9.995652

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model3 = growth_model.growth_model_3()

def get_mod_3_params():
    r = 6.198824e-2 #0.061
    lambda_h = 3.104945e-2 #0.052
    lambda_o = 6.356908e0 #0.448
    lambda_odh = 4.236145e-2 #0.362
    tau_o = 3.434915e0 #0.181
    tau_d = 3.911236e-3 #0.384
    tau_h = 1.052131e-2 #0.064
    lambda_dh = 9.557923e0 #31.793
    return [r, lambda_h, lambda_o, lambda_odh, tau_o, tau_d, tau_h, lambda_dh]

    

model3.sim_graph_model(get_mod_3_params())
# Out:
# r = 0.06198824
# lambda_h = 0.03104945
# lambda_o = 6.356908
# lambda_odh = 0.04236145
# tau_o = 3.434915
# tau_d = 0.003911236
# tau_h = 0.01052131
# lambda_dh = 9.557923

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
    
model4 = growth_model.growth_model_4()

def get_mod_4_params():
    r = 6.197490e-2 #0.061
    lambda_o = 1.428324e1 #0.135
    lambda_oh = 6.171914e-2 #0.187
    lambda_odh = 1.547911e-1 #0.741
    tau_o = 3.087974e1 #0.143
    tau_d = 1.173226e-4 #0.07
    tau_h = 4.565477e-3 #0.612
    lambda_dh = 9.658535e0 #25.548
    return [r, lambda_o, lambda_oh, lambda_odh, tau_o, tau_d, tau_h, lambda_dh]


model4.sim_graph_model(get_mod_4_params())
# Out:
# r = 0.0619749
# lambda_o = 14.28324
# lambda_oh = 0.06171914
# lambda_odh = 0.1547911
# tau_o = 30.87974
# tau_d = 0.0001173226
# tau_h = 0.004565477
# lambda_dh = 9.658535
